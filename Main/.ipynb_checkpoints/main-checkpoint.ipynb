# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# temporary file locations (DELETE BEFORE SUBMISSION)
mouse_metadata_path = '/Users/Brianna/Desktop/JHUmaterials/Submissions/matplotlib-challenges/Resources/Mouse_metadata.csv'
study_results_path = '/Users/Brianna/Desktop/JHUmaterials/Submissions/matplotlib-challenges/Resources/Study_results.csv'
# Study data files (UNCOMMENT BEFORE SUBMISSION)
# mouse_metadata_path = 'Resources/Mouse_metadata.csv'
# study_results_path = 'Resources/Study_results.csv'

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_df = pd.merge(mouse_metadata, study_results, on='Mouse ID', how='inner')
# Display the data table for preview
mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
num_of_mice = len(mouse_df['Mouse ID'])
num_of_mice
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicates_df = mouse_df[mouse_df.duplicated(subset=['Mouse ID','Timepoint'], keep=False)]
duplicates_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
total_duplicates_df = mouse_df[mouse_df.duplicated(subset=['Mouse ID'])]
total_duplicates_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_df = mouse_df.drop_duplicates(subset=['Mouse ID'])
clean_mouse_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
unique_mice_clean = len(clean_mouse_df['Mouse ID'])
unique_mice_clean
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each drug regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
    # mean, median, variance, standard deviation, and SEM of the tumor volume. 
    # Assemble the resulting series into a single summary dataframe.

mean = mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
std = mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

summary_stats = pd.DataFrame({'Mean': mean, 
                              'Median': median, 
                              'Variance': variance, 
                              'Standard Deviation': std, 
                              'SEM': sem})
summary_stats
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
summary_table = mouse_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)':['mean','median','var','std', 'sem']})
summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

# group mouse data by drug regimen
grouped_drugs = pd.DataFrame(mouse_df.groupby(['Drug Regimen']).count()).reset_index()

# grab drug regimen and mouse id columns
regimen_df = grouped_drugs[['Drug Regimen', 'Mouse ID']]
regimen_df = regimen_df.set_index('Drug Regimen')

# create bar chart
regimen_df.plot(kind="bar", figsize=(8,3), color='g')
plt.title('Measurement Count Based on Drug Treatment')
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

# create array of datapoint numbers from regimen_df 
data_points = [num for num in regimen_df['Mouse ID']]

# set x-axis as number of drug regimens
x_axis = np.arange(len(regimen_df))
plt.bar(x_axis, data_points, color='b', alpha=0.75, align='center')

# place tick labels
tick_labels = [value for value in x_axis]
plt.xticks(tick_labels, ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],  rotation='vertical')

# clean up formatting
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(data_points)+10)

# place title, xlabel, ylabel
plt.title('Measurement Count Based on Drug Treatment')
plt.xlabel('Drug Regimen')
plt.ylabel('No. of Data Points')
# Out:
# Text(0, 0.5, 'No. of Data Points')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# group clean_mouse_df by sex and mouse id
grouped_gender = clean_mouse_df.groupby(['Mouse ID', 'Sex'])
gender_df = pd.DataFrame(grouped_gender.size())

# create gender dataframe with total count for each sex
mouse_gender = pd.DataFrame(gender_df.groupby(['Sex']).count())
mouse_gender.columns = ['Total']

# calculate percentages
mouse_gender['Percentage'] = (100*(mouse_gender['Total']/mouse_gender['Total'].sum()))

mouse_gender['Percentage'] = mouse_gender['Percentage']

mouse_gender
# Out:
#         Total  Percentage
# Sex
# Female    124   49.799197
# Male      125   50.200803

# %%
# generate pie plot using pandas
plot = mouse_gender.plot.pie(y='Total',
                             figsize=(5,5), 
                             colors = ['purple', 'green'], 
                             startangle=140, 
                             explode = (0.1, 0), 
                             shadow = True, 
                             autopct='%1.1f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels = ['Female', 'Male']
values = [49.799197, 50.200803]
colors = ['purple', 'green']
explode = (0.1, 0)

# generate pie plot using pyplt
plt.pie(values, explode = explode, labels = labels, colors = colors, autopct = '%1.1f%%', shadow = True, startangle = 140)
plt.axis('equal')
# Out:
# (-1.1879383453817904,
#  1.111754351424799,
#  -1.1987553745848882,
#  1.1126035084692154)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
    # Capomulin, Ramicane, Infubinol, and Ceftamin
    
# Start by getting the last (greatest) timepoint for each mouse
four_drugs = mouse_df[mouse_df['Drug Regimen'].isin(['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])]
four_drugs = four_drugs.sort_values(['Timepoint'], ascending=True)

four_drugs_data = four_drugs[['Drug Regimen', 'Mouse ID', 'Timepoint', 'Tumor Volume (mm3)']]
four_drugs_data.reset_index(drop=True)
# Out:
#     Drug Regimen Mouse ID  Timepoint  Tumor Volume (mm3)
# 0       Ramicane     k403          0           45.000000
# 1      Infubinol     q132          0           45.000000
# 2      Capomulin     i738          0           45.000000
# 3       Ramicane     a520          0           45.000000
# 4       Ceftamin     p438          0           45.000000
# ..           ...      ...        ...                 ...
# 809    Capomulin     v923         45           40.658124
# 810    Capomulin     m957         45           33.329098
# 811    Capomulin     j119         45           38.125164
# 812     Ramicane     s508         45           30.276232
# 813    Infubinol     z581         45           62.754451
#
# [814 rows x 4 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
four_drugs_sort = four_drugs_data.groupby(['Drug Regimen', 'Mouse ID']).last()['Tumor Volume (mm3)']
four_drugs_df = four_drugs_sort.to_frame()
four_drugs_df
# Out:
#                        Tumor Volume (mm3)
# Drug Regimen Mouse ID
# Capomulin    b128               38.982878
#              b742               38.939633
#              f966               30.485985
#              g288               37.074024
#              g316               40.159220
# ...                                   ...
# Ramicane     s508               30.276232
#              u196               40.667713
#              w678               43.166373
#              y449               44.183451
#              z578               30.638696
#
# [100 rows x 1 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.    
# Locate the rows which contain mice on each drug and get the tumor volumes
iqr_drug = four_drugs_df['Tumor Volume (mm3)']

# add subset 
quartiles = iqr_drug.quantile([.25,.5,.75])
lowerq = quartiles[.25]
upperq = quartiles[.75]
iqr = upperq-lowerq 

# Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f'Lower Bound: {lower_bound} \nUpper Bound: {upper_bound}')
# Out:
# Lower Bound: 3.0739668737499812
# Upper Bound: 94.04403868375002

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tumor_vol_data = four_drugs_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].apply(list)
tumor_vol_df = pd.DataFrame(tumor_vol_data)
tumor_vol_df = tumor_vol_df.reindex(treatments)
tumor_vols = [vol for vol in tumor_vol_df['Tumor Volume (mm3)']]

# create box plot
plt.boxplot(tumor_vols, labels=treatments)
plt.ylim(10, 80)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
time_vs_tumer = mouse_df[mouse_df['Mouse ID'].isin(['j119'])]
time_vs_tumer_data = time_vs_tumer[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)']]

line_plot_df = time_vs_tumer_data.reset_index()
line_plot_final = line_plot_df[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)']]

lines = line_plot_final.plot.line()

tumorvolume_list = line_plot_final['Tumor Volume (mm3)'].tolist()
timepoint_list = line_plot_final['Timepoint'].tolist()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_scatter = mouse_df[mouse_df['Drug Regimen'].isin(['Capomulin'])]

capomulin_scatter_df = four_drugs[['Mouse ID','Weight (g)', 'Tumor Volume (mm3)']]

capomulin_sorted = capomulin_scatter_df.sort_values(['Weight (g)'], ascending=True)

capomulin_scatter_plot = capomulin_scatter.reset_index()

capomulin_grouped_weight = capomulin_scatter_plot.groupby('Weight (g)')['Tumor Volume (mm3)'].mean()

capomulin_grouped = pd.DataFrame(capomulin_grouped_weight).reset_index()


#capomulin_scatter = capomulin_grouped_weight.plot.scatter(x='Weight (g)', y='Tumor Volume (mm3)')
#
capomulin_scatter = capomulin_grouped.plot(kind='scatter', x='Weight (g)', y='Tumor Volume (mm3)', grid = True, figsize= (8,8))
#capomulin_scatter

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin_grouped['Weight (g)']
y_values = capomulin_grouped['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# generate scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(6,10),fontsize=10,color='red')
plt.xlabel('Weight')
plt.ylabel('Tumor Volume')
plt.title('Weight Vs. Avg Tumor Vol')
plt.show()
